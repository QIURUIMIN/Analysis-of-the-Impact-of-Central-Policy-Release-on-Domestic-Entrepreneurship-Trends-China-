# %%
from urllib.request import urlopen

# if has Chinese, apply decode()
html = urlopen(
    "http://www.gov.cn/xinwen/2021-05/02/content_5604475.htm"
).read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head><script id="allmobilize" charset="utf-8" src="//ysp.www.gov.cn/013582404bd78ad3c016b8fffefe6a9a/allmobilize.min.js"></script><meta http-equiv="Cache-Control" content="no-siteapp" /><link rel="alternate" media="handheld" href="#"/>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <meta http-equiv="x-ua-compatible" content="IE=edge" >
# <link href="http://www.gov.cn/govweb/xhtml/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <title>习近平与青年的故事_滚动新闻_中国政府网</title>
# <meta name="others" content="页面生成时间 2021-05-03 11:12:42" />
# <meta name="template,templategroup,version" content="2486,100039,8.3" />
# <meta name="keywords" content="">
# <meta name="description" content='跨越半个世纪，从沟壑纵横的陕北高原一路走来，习近平总书记深知青年的渴望，格外关心青年的成长。与青年通信，同青年谈心，参加青年活动，常把青年记挂心间。深情嘱托、诚挚盼望，为青年在奋斗前行的道路上点亮航标、指引航程。,2021-05-02-13:05:00' />
# <meta name="catalog" content="c1443">
# ...

# %%
import re
res = re.findall(r"<title>(.+?)</title>", html)
print("\nPage title is: ", res[0])
# Out:
# Page title is:  习近平与青年的故事_滚动新闻_中国政府网

# %%
res = re.findall(r"<p(.*?)</p>", html, flags=re.DOTALL)
print("\nPage paragraph is:", res[0])
# Out:
# Page paragraph is:  style="text-indent: 2em; font-family: 宋体; font-size: 12pt;"><span style="font-family: 宋体; font-size: 12pt;">新华社北京5月2日电 <span style="font-weight: bold; color: rgb(51, 51, 153);">题：习近平与青年的故事</span></span>

# %%
import re
 
str = 'aabbabaabbaa'

# 一个"."就是匹配除 \n (换行符)以外的任意一个字符
print(re.findall(r'a.b',str))#['aab', 'aab']
# Out:
# ['aab', 'aab']

# %%
res = re.findall(r'href="(.*?)"', html)
print("\nAll links: ", res)
# Out:
# All links:  ['#', 'http://www.gov.cn/govweb/xhtml/favicon.ico', '/govweb/xhtml/2016gov/css/base.css', '/govweb/xhtml/2016gov/css/common.css', '/govweb/xhtml/2016gov/css/common_detail.css', '/govweb/xhtml/2016gov/css/common_detail_n920.css', '/govweb/xhtml/2016gov/public/share2020/resources/shareStyle.css', '/govweb/xhtml/2016gov/css/date.css', 'http://www.gov.cn/fuwu/jiucuo.htm', '/xinwen/2021-04/20/content_5600905.htm', '/xinwen/2021-04/30/content_5604221.htm', 'http://www.gov.cn/public/yidongkehuduan.htm', 'http://www.gov.cn/home/2014-02/18/content_5046260.htm', 'http://www.gov.cn/public/yidongkehuduan.htm', 'https://liuyan.www.gov.cn/wxzlsjh/index.htm', 'http://www.gov.cn/home/2014-02/18/content_5046260.htm']

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
soup = BeautifulSoup(html, features='lxml')
print(soup.h1)
print('\n', soup.p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-53216c1e6c63> in <module>
# ----> 1 soup = BeautifulSoup(html, features='lxml')
#       2 print(soup.h1)
#       3 print('\n', soup.p)
#
# NameError: name 'BeautifulSoup' is not defined

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# if has Chinese, apply decode()
html = urlopen("http://www.gov.cn/xinwen/2021-05/02/content_5604475.htm").read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head><script id="allmobilize" charset="utf-8" src="//ysp.www.gov.cn/013582404bd78ad3c016b8fffefe6a9a/allmobilize.min.js"></script><meta http-equiv="Cache-Control" content="no-siteapp" /><link rel="alternate" media="handheld" href="#"/>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <meta http-equiv="x-ua-compatible" content="IE=edge" >
# <link href="http://www.gov.cn/govweb/xhtml/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <title>习近平与青年的故事_滚动新闻_中国政府网</title>
# <meta name="others" content="页面生成时间 2021-05-03 11:12:42" />
# <meta name="template,templategroup,version" content="2486,100039,8.3" />
# <meta name="keywords" content="">
# <meta name="description" content='跨越半个世纪，从沟壑纵横的陕北高原一路走来，习近平总书记深知青年的渴望，格外关心青年的成长。与青年通信，同青年谈心，参加青年活动，常把青年记挂心间。深情嘱托、诚挚盼望，为青年在奋斗前行的道路上点亮航标、指引航程。,2021-05-02-13:05:00' />
# <meta name="catalog" content="c1443">
# ...

# %%
soup = BeautifulSoup(html, features='lxml')
print(soup.h1)

"""
<h1>爬虫测试1</h1>
"""

print('\n', soup.p)

"""
<p>
        这是一个在 <a href="https://mofanpy.com/">莫烦Python</a>
<a href="https://mofanpy.com/tutorials/scraping">爬虫教程</a> 中的简单测试.
    </p>
"""
# Out:
# <h1>
#         习近平与青年的故事
#       </h1>
#
#  <p style="text-indent: 2em; font-family: 宋体; font-size: 12pt;"><span style="font-family: 宋体; font-size: 12pt;">新华社北京5月2日电 <span style="font-weight: bold; color: rgb(51, 51, 153);">题：习近平与青年的故事</span></span></p>
# '\n<p>\n        这是一个在 <a href="https://mofanpy.com/">莫烦Python</a>\n<a href="https://mofanpy.com/tutorials/scraping">爬虫教程</a> 中的简单测试.\n    </p>\n'

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
import random


base_url = "https://baike.baidu.com"
his = ["/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711"]

# %%
url = base_url + his[-1]
print(url)

html = urlopen(url).read().decode('utf-8')
soup = BeautifulSoup(html, features='lxml')
print(soup.find('h1').get_text(), '    url: ', his[-1])

# 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# Out:
# https://baike.baidu.com/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711

# %%
# find valid urls
sub_urls = soup.find_all("a", {"target": "_blank", "href": re.compile("/item/(%.{2})+$")})
print(sub_urls)
if len(sub_urls) != 0:
    his.append(random.sample(sub_urls, 1)[0]['href'])
else:
    # no valid sub link found
    his.pop()
print(his)

# ['/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711', '/item/%E4%B8%8B%E8%BD%BD%E8%80%85']
# Out:
# [<a href="/item/%E7%BD%91%E7%BB%9C" target="_blank">网络</a>, <a href="/item/%E4%B8%87%E7%BB%B4%E7%BD%91" target="_blank">万维网</a>, <a href="/item/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E" target="_blank">搜索引擎</a>, <a href="/item/%E9%80%9A%E7%94%A8%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E" target="_blank">通用搜索引擎</a>, <a href="/item/%E7%BD%91%E7%BB%9C%E6%95%B0%E6%8D%AE" target="_blank">网络数据</a>, <a href="/item/%E4%B8%87%E7%BB%B4%E7%BD%91" target="_blank">万维网</a>, <a href="/item/%E7%BD%91%E7%BB%9C%E6%8A%80%E6%9C%AF" target="_blank">网络技术</a>, <a href="/item/%E9%80%9A%E7%94%A8%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E" target="_blank">通用搜索引擎</a>, <a href="/item/%E5%85%B3%E9%94%AE%E5%AD%97" target="_blank">关键字</a>, <a href="/item/%E4%B8%87%E7%BB%B4%E7%BD%91" target="_blank">万维网</a>, <a href="/item/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E" target="_blank">搜索引擎</a>, <a href="/item/%E6%90%9C%E7%B4%A2%E7%AD%96%E7%95%A5" target="_blank">搜索策略</a>, <a href="/item/%E6%8E%92%E5%BA%8F%E7%AE%97%E6%B3%95" target="_blank">
# ...

# %%
his = ["/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711"]

for i in range(20):
    url = base_url + his[-1]

    html = urlopen(url).read().decode('utf-8')
    soup = BeautifulSoup(html, features='lxml')
    print(i, soup.find('h1').get_text(), '    url: ', his[-1])
# Out:
# 0 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 1 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 2 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 3 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 4 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 5 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 6 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 7 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 8 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 9 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 10 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 11 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 12 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 13 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# ...

# %%
# find valid urls
sub_urls = soup.find_all("a", {"target": "_blank", "href": re.compile("/item/(%.{2})+$")})

if len(sub_urls) != 0:
    his.append(random.sample(sub_urls, 1)[0]['href'])
else:
    # no valid sub link found
    his.pop()
print(his)

# ['/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711', '/item/%E4%B8%8B%E8%BD%BD%E8%80%85']
# Out:
# ['/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711', 'https://baike.baidu.com/item/%E7%99%BE%E5%BA%A6%E7%99%BE%E7%A7%91%EF%BC%9A%E5%88%9B%E5%BB%BA%E7%89%88%E6%9C%AC']

# %%
his = ["/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711"]

for i in range(10):
    url = base_url + his[-1]
    html = urlopen(url).read().decode('utf-8')
    soup = BeautifulSoup(html, features='lxml')
    print(i, soup.find('h1').get_text(), '    url: ', his[-1])

    # find valid urls
    sub_urls = soup.find_all("a", {"target": "_blank", "href": re.compile("/item/(%.{2})+$")})

    if len(sub_urls) != 0:
        his.append(random.sample(sub_urls, 1)[0]['href'])
    else:
        # no valid sub link found
        his.pop()
# Out:
# 0 网络爬虫     url:  /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 1 深度优先策略     url:  /item/%E6%B7%B1%E5%BA%A6%E4%BC%98%E5%85%88%E7%AD%96%E7%95%A5
# 2 宽度优先搜索     url:  /item/%E5%B9%BF%E5%BA%A6%E4%BC%98%E5%85%88%E7%AD%96%E7%95%A5
# 3 邻接表     url:  /item/%E9%82%BB%E6%8E%A5%E8%A1%A8
# 4 无向图     url:  /item/%E6%97%A0%E5%90%91%E5%9B%BE
# 5 有边     url:  /item/%E6%9C%89%E8%BE%B9
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
# ...

# %%
<div><textarea class="scriptInput">payload = {'username': 'Morvan', 'password': 'password'}
r = requests.post('http://pythonscraping.com/pages/cookies/welcome.php', data=payload)
print(r.cookies.get_dict())

# {'username': 'Morvan', 'loggedin': '1'}
# Out:
#   File "<ipython-input-16-86ce6efc9886>", line 1
#     <div><textarea class="scriptInput">payload = {'username': 'Morvan', 'password': 'password'}
#     ^
# SyntaxError: invalid syntax

# %%
import os
os.makedirs('C:\\Users\\HONEYMOON\\Desktop\\规划', exist_ok=True)

IMAGE_URL = "https://mofanpy.com/static/img/description/learning_step.png"

# %%
from urllib.request import urlretrieve
urlretrieve(IMAGE_URL, 'C:\\Users\\HONEYMOON\\Desktop\\规划\\p1.png')
# Out:
# ('C:\\Users\\HONEYMOON\\Desktop\\规划\\p1.png',
#  <http.client.HTTPMessage at 0x22a7788f8d0>)

# %%
import requests
r = requests.get(IMAGE_URL)
with open('C:\\Users\\HONEYMOON\\Desktop\\规划\\p2.png', 'wb') as f:
    f.write(r.content)

# %%
r = requests.get(IMAGE_URL, stream=True)    # stream loading

with open('./img/image3.png', 'wb') as f:
    for chunk in r.iter_content(chunk_size=32):
        f.write(chunk)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-87032998bd1a> in <module>
#       1 r = requests.get(IMAGE_URL, stream=True)    # stream loading
#       2
# ----> 3 with open('./img/image3.png', 'wb') as f:
#       4     for chunk in r.iter_content(chunk_size=32):
#       5         f.write(chunk)
#
# FileNotFoundError: [Errno 2] No such file or directory: './img/image3.png'

# %%
from bs4 import BeautifulSoup
import requests

URL = "http://www.ngchina.com.cn/animals/"

# %%
html = requests.get(URL).text
soup = BeautifulSoup(html, 'lxml')
img_ul = soup.find_all('ul', {"class": "img_list"})

# %%
import os
os.makedirs('C:\\Users\\HONEYMOON\\Desktop\\规划', exist_ok=True)

# %%
for ul in img_ul:
    imgs = ul.find_all('img')
    for img in imgs:
        url = img['src']
        r = requests.get(url, stream=True)
        image_name = url.split('/')[-1]
        with open('C:/Users/HONEYMOON/Desktop/规划/%s' % image_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=128):
                f.write(chunk)
        print('Saved %s' % image_name)
# Out:
# Saved 20210507102144893.jpg
# Saved 20210506100541861.jpg
# Saved 20210426103542715.jpg
# Saved 20210425112503823.jpg
# Saved 20210423111951974.jpg
# Saved 20210423100102836.jpg

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
def getHTML(url):
    try:
        r = requests.get(url,timeout=30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return 

def getContent(url):
    html = getHTML(url)
    soup = BeautifulSoup(html,'html.parser')
    title = soup.select('div.mbtitle')
    paras_tmp = soup.select('p')
    paras = paras_tmp[3:]
    return paras
 
def saveFile(text):
    f=open('novel.txt','w',encoding='utf-8')
    for t in text:
        if len(t) > 0:
            f.writelines(t.get_text() + "\n")
    f.close()
    
def finish(url):
    text = getContent(url)
    saveFile(text)

    
def f_txt():
    df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
    web = df['网址']
    web_lst = []
    for w in web:
        web_lst.append(w)
    for url in web_lst:
        finish(url)

# %%
import jieba
import requests
dics_counts={}
lst=[]
def txt_to_sta():
    lst_top3=[]
    df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
    web = df['网址']
    web_lst = []
    for w in web:
        web_lst.append(w)
    for url in web_lst[140:172]:
        print(web_lst.index(url)+2)
        print(url)
        finish(url)
        txt = open('novel.txt', encoding="utf-8").read()
        #加载停用词表
        stopwords = [line.strip() for line in open(r"D:\try\停用词.txt",encoding="utf-8").readlines()]
        words  = jieba.lcut(txt)
        counts = {}
        lst_top3=[]
        for word in words:
        #不在停用词表中
            if word not in stopwords:
            #不统计字数为一的词
                if len(word) == 1:
                    continue
                else:
                    counts[word] = counts.get(word,0) + 1
        items = list(counts.items())
        items.sort(key=lambda x:x[1], reverse=True)
        for i in range(3):
            word, count = items[i]
            if word.isdigit():
                continue
            else:
                dics_counts[word]=dics_counts.get(word,0)+1
                lst_top3.append(word)
        lst.append(lst_top3)

        print(dics_counts)
        print(lst_top3)
        print(lst)
        '''print(counts)
        print(items)'''
        print()
    
txt_to_sta()
# Out:
# 142
# http://www.gov.cn/zhengce/2015-05/13/content_5023731.htm
# {'商务部': 1, '互联网': 1, '流通': 1}
# ['商务部', '互联网', '流通']
# [['商务部', '互联网', '流通']]
# {'联系人': 1, '商务部': 2, '电子商务': 1, '费云高': 1, '010': 1, '65197477': 1, 'feiyungao': 1, 'mofcom': 1, 'gov': 1, 'cn': 1, '办公厅': 1, '附件': 1, '互联网': 2, '流通': 2, '行动计划': 1, '信息': 1, '进村': 1, '入户': 1, '试点工作': 1, '安排': 1, '解读': 1, '评论': 1, '商贸': 1, '零售': 1, '行业': 1, '改革': 1, '转型': 1, '交谊舞': 1}
# [('商务部', 2), ('互联网', 2), ('流通', 2), ('联系人', 1), ('电子商务', 1), ('费云高', 1), ('010', 1), ('65197477', 1), ('feiyungao', 1), ('mofcom', 1), ('gov', 1), ('cn', 1), ('办公厅', 1), ('附件', 1), ('行动计划', 1), ('信息', 1), ('进村', 1), ('入户', 1), ('试点工作', 1), ('安排', 1), ('解读', 1), ('评论', 1), ('商贸', 1), ('零售', 1), ('行业', 1), ('改革', 1), ('转型', 1), ('交谊舞', 1)]
#
# 143
# http://www.gov.cn/zhengce/zhengceku/2015-05/01/content_9688.htm
# ---------------------------------------------------------------------------
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中.xlsx')
web = df['网址']
web_lst = []
for w in web:
    web_lst.append(w)
print(web_lst)
# Out:
# ['http://www.gov.cn/zhengce/content/2020-12/24/content_5572999.htm', 'http://www.mohrss.gov.cn/SYrlzyhshbzb/rdzt/zyjntsxd/zyjntsxd_xdjz/202011/t20201119_397882.html', 'http://www.mohrss.gov.cn/SYrlzyhshbzb/rdzt/zyjntsxd/zyjntsxd_xdzn/202011/t20201117_397433.html']

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
def getHTML(url):
        r = requests.get(url,timeout=30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text

def getContent(url):
    html = getHTML(url)
    soup = BeautifulSoup(html,'html.parser')
    title = soup.select('div.mbtitle')
    paras_tmp = soup.select('p')
    paras = paras_tmp[3:]
    return paras
 
def saveFile(text):
    f=open('novel.txt','w',encoding='utf-8')
    for t in text:
        if len(t) > 0:
            f.writelines(t.get_text() + "\n")
    f.close()
    
def finish():
    url = 'http://www.mva.gov.cn/gongkai/zfxxgkpt/fdzdgknr/fgzc/gfxwj/201903/t20190322_23514.html'
    text = getContent(url)
    saveFile(text)

# %%
finish()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-95-543976c7b8fc> in <module>
# ----> 1 finish()
#
# <ipython-input-94-4c2ccb2d6267> in finish()
#      26 def finish():
#      27     url = 'http://www.mva.gov.cn/gongkai/zfxxgkpt/fdzdgknr/fgzc/gfxwj/201903/t20190322_23514.html'
# ---> 28     text = getContent(url)
#      29     saveFile(text)
#
# <ipython-input-94-4c2ccb2d6267> in getContent(url)
#      10
#      11 def getContent(url):
# ---> 12     html = getHTML(url)
#      13     soup = BeautifulSoup(html,'html.parser')
#      14     title = soup.select('div.mbtitle')
#
# <ipython-input-94-4c2ccb2d6267> in getHTML(url)
#       5 def getHTML(url):
#       6         r = requests.get(url,timeout=30)
# ----> 7         r.raise_for_status()
#       8         r.encoding = r.apparent_encoding
#       9         return r.text
#
# ...

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
def getHTML(url):
    try:
        r = requests.get(url,timeout=30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return 

def getContent(url):
    html = getHTML(url)
    soup = BeautifulSoup(html,'html.parser')
    title = soup.select('div.mbtitle')
    paras_tmp = soup.select('p')
    paras = paras_tmp[3:]
    return paras
 
def saveFile(text):
    f=open('novel.txt','w',encoding='utf-8')
    for t in text:
        if len(t) > 0:
            f.writelines(t.get_text() + "\n")
    f.close()
    
def finish(url):
    text = getContent(url)
    saveFile(text)

    
def f_txt():
    df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
    web = df['网址']
    web_lst = []
    for w in web:
        web_lst.append(w)
    for url in web_lst:
        finish(url)



def web(ulr):
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.146 Safari/537.36'
    }
    res = requests.get(url, headers=headers)
    res.encoding='utf-8'
    soup = BeautifulSoup(res.text, 'lxml')

    # 找出class属性值为pages_content的div
    news_list = soup.find('div', {'class': 'pages_content'})
    #pages_content wrap Custom_UnionStyle scy-main gsj_htmlcon warp  ccontent center
    if news_list==None:
        for x in ['wrap','zw-con']:
            news_list = soup.find('div', {'class': x})
            if news_list!=None:
                break
    # 找出news_list下的所有p标签
    news = news_list.find_all('p')

    txt=open('novel.txt','w')
    for x in news:
        a=x.text
        txt.write(a)

# %%
import jieba
import requests
dics_counts={}
lst=[]
def txt_to_sta():
    lst_top3=[]
    df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
    web = df['网址']
    web_lst = []
    for w in web:
        web_lst.append(w)
    for url in web_lst[140:172]:
        print(web_lst.index(url)+2)
        print(url)
        try:
            finish(url)
        except:
            try:
                web(url)
            except IndexError:
                pass
        txt = open('novel.txt', encoding="utf-8").read()
        #加载停用词表
        stopwords = [line.strip() for line in open(r"D:\try\停用词.txt",encoding="utf-8").readlines()]
        words  = jieba.lcut(txt)
        counts = {}
        lst_top3=[]
        for word in words:
        #不在停用词表中
            if word not in stopwords:
            #不统计字数为一的词
                if len(word) == 1:
                    continue
                else:
                    counts[word] = counts.get(word,0) + 1
        items = list(counts.items())
        items.sort(key=lambda x:x[1], reverse=True)
        for i in range(3):
            word, count = items[i]
            if word.isdigit():
                continue
            else:
                dics_counts[word]=dics_counts.get(word,0)+1
                lst_top3.append(word)
        lst.append(lst_top3)

        print(dics_counts)
        print(lst_top3)
        print(lst)
        print(counts)
        print(items)
        print()
    
txt_to_sta()
# Out:
# 142
# http://www.gov.cn/zhengce/2015-05/13/content_5023731.htm
# {'商务部': 1, '互联网': 1, '流通': 1}
# ['商务部', '互联网', '流通']
# [['商务部', '互联网', '流通']]
# {'联系人': 1, '商务部': 2, '电子商务': 1, '费云高': 1, '010': 1, '65197477': 1, 'feiyungao': 1, 'mofcom': 1, 'gov': 1, 'cn': 1, '办公厅': 1, '附件': 1, '互联网': 2, '流通': 2, '行动计划': 1, '信息': 1, '进村': 1, '入户': 1, '试点工作': 1, '安排': 1, '解读': 1, '评论': 1, '商贸': 1, '零售': 1, '行业': 1, '改革': 1, '转型': 1, '交谊舞': 1}
# [('商务部', 2), ('互联网', 2), ('流通', 2), ('联系人', 1), ('电子商务', 1), ('费云高', 1), ('010', 1), ('65197477', 1), ('feiyungao', 1), ('mofcom', 1), ('gov', 1), ('cn', 1), ('办公厅', 1), ('附件', 1), ('行动计划', 1), ('信息', 1), ('进村', 1), ('入户', 1), ('试点工作', 1), ('安排', 1), ('解读', 1), ('评论', 1), ('商贸', 1), ('零售', 1), ('行业', 1), ('改革', 1), ('转型', 1), ('交谊舞', 1)]
#
# 143
# http://www.gov.cn/zhengce/zhengceku/2015-05/01/content_9688.htm
# ---------------------------------------------------------------------------
# ...

# %%
import jieba
import requests
dics_counts={}
lst=[]
def txt_to_sta():
    lst_top3=[]
    df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
    web = df['网址']
    web_lst = []
    for w in web:
        web_lst.append(w)
    for url in web_lst[141:142]:
        print(web_lst.index(url)+2)
        print(url)
        web(url)

        txt = open('novel.txt', encoding="utf-8").read()
        print(txt)

# %%
txt_to_sta()
# Out:
# 143
# http://www.gov.cn/zhengce/zhengceku/2015-05/01/content_9688.htm
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-44c4f8f0e49a> in <module>
# ----> 1 txt_to_sta()
#
# <ipython-input-176-23fdd774d50d> in txt_to_sta()
#      13         print(web_lst.index(url)+2)
#      14         print(url)
# ---> 15         web(url)
#      16
#      17         txt = open('novel.txt', encoding="utf-8").read()
#
# TypeError: 'Series' object is not callable

# %%
def web(u):
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.146 Safari/537.36'
    }
    url = u
    res = requests.get(url, headers=headers)
    res.encoding='utf-8'
    soup = BeautifulSoup(res.text, 'lxml')

    # 找出class属性值为pages_content的div
    news_list = soup.find('div', {'class': 'pages_content'})
    #pages_content wrap Custom_UnionStyle scy-main gsj_htmlcon warp  ccontent center
    if news_list==None:
        for x in ['wrap','zw-con']:
            news_list = soup.find('div', {'class': x})
            if news_list!=None:
                break
    # 找出news_list下的所有p标签
    news = news_list.find_all('p')

    txt=open('try.txt','w')
    for x in news:
        a=x.text
        txt.write(a)


def web2(u):
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.146 Safari/537.36'
    }
    url = u
    res = requests.get(url, headers=headers)
    res.encoding='GB2312'
    soup = BeautifulSoup(res.text, 'lxml')

    # 找出class属性值为pages_content的div
    news_list = soup.find('div', {'class': 'zw-con'})
    #pages_content wrap Custom_UnionStyle scy-main gsj_htmlcon warp  ccontent center
    if news_list==None:
        main_text_element = soup.find('td', {'class': 'black14'})
        for style_element in soup.find_all('style'):
            style_element.decompose()
        
        news_list=main_text_element
    # 找出news_list下的所有p标签
    news = news_list.find_all('p')

    txt=open('try.txt','w')
    for x in news:
        a=x.text
        txt.write(a)

# %%
def web(u):
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.146 Safari/537.36'
    }
    url = u
    res = requests.get(url, headers=headers)
    res.encoding='gbk'
    soup = BeautifulSoup(res.text, 'lxml')

    # 找出class属性值为pages_content的div
    news_list = soup.find('div', {'class': 'pages_content'})
    #pages_content wrap Custom_UnionStyle scy-main gsj_htmlcon warp  ccontent center
    if news_list==None:
        for x in ['wrap','zw-con']:
            news_list = soup.find('div', {'class': x})
            if news_list!=None:
                break
    # 找出news_list下的所有p标签
    news = news_list.find_all('p')

    txt=open('try.txt','w')
    for x in news:
        a=x.text
        txt.write(a)
        
        
def web2(u):
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.146 Safari/537.36'
    }
    url = u
    res = requests.get(url, headers=headers)
    res.encoding='GB2312'
    soup = BeautifulSoup(res.text, 'lxml')

    # 找出class属性值为pages_content的div
    news_list = soup.find('div', {'class': 'zw-con'})
    #pages_content wrap Custom_UnionStyle scy-main gsj_htmlcon warp  ccontent center
    if news_list==None:
        main_text_element = soup.find('td', {'class': 'black14'})
        for style_element in soup.find_all('style'):
            style_element.decompose()
        
        news_list=main_text_element
    # 找出news_list下的所有p标签
    news = news_list.find_all('p')

    txt=open('try.txt','w')
    for x in news:
        a=x.text
        txt.write(a)

# %%
def ff():
        import requests
        from bs4 import BeautifulSoup
        import jieba
        import requests
        df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
        web = df['网址']
        web_lst = []
        for w in web:
            web_lst.append(w)
        lst = []
        dics_counts={}
        for u in web_lst[0:10]:
            print(web_lst.index(u)+2)
            try:
                web(u)
            except:
                try:
                    web2(u)
                except:
                    print(u)
            txt = open('try.txt',encoding = 'utf-8').read()
            print(txt)
            #加载停用词表
            stopwords = [line.strip() for line in open(r"D:\try\停用词.txt",encoding="utf-8").readlines()]
            words  = jieba.lcut(txt)
            counts = {}
            lst_top3=[]
            for word in words:
            #不在停用词表中
                if word not in stopwords:
                #不统计字数为一的词
                    if len(word) == 1:
                        continue
                    else:
                        counts[word] = counts.get(word,0) + 1
            items = list(counts.items())
            items.sort(key=lambda x:x[1], reverse=True)
            for i in range(3):
                word, count = items[i]
                if word.isdigit():
                    continue
                else:
                    dics_counts[word]=dics_counts.get(word,0)+1
                    lst_top3.append(word)
            lst.append(lst_top3)

            print(dics_counts)
            print(lst_top3)
            print(lst)
            '''print(counts)
            print(items)'''
            print()

# %%
ff()
# Out:
# 2
# http://www.gov.cn/zhengce/content/2020-12/24/content_5572999.htm
#     联系人：商务部电子商务司  费云高
#     电  话：010-65197477
#     邮  箱：feiyungao@mofcom.gov.cn
#
#
# 商务部办公厅
# 2015年5月13日
# 附件：
# 1、“互联网+流通”行动计划
# 2、2015年信息进村入户试点工作安排
# 解读评论：
# 商贸零售行业：“互联网+流通”与“改革+转型”的交谊舞
#
# {'商务部': 1, '互联网': 1, '流通': 1}
# ['商务部', '互联网', '流通']
# [['商务部', '互联网', '流通']]
#
# 3
# http://www.mohrss.gov.cn/SYrlzyhshbzb/rdzt/zyjntsxd/zyjntsxd_xdjz/202011/t20201119_397882.html
#     联系人：商务部电子商务司  费云高
#     电  话：010-65197477
#     邮  箱：feiyungao@mofcom.gov.cn
#
#
# 商务部办公厅
# 2015年5月13日
# 附件：
# 1、“互联网+流通”行动计划
# 2、2015年信息进村入户试点工作安排
# 解读评论：
# 商贸零售行业：“互联网+流通”与“改革+转型”的交谊舞
#
# {'商务部': 2, '互联网': 2, '流通': 2}
# ['商务部', '互联网', '流通']
# [['商务部', '互联网', '流通'], ['商务部', '互联网', '流通']]
#
# 4
# http://www.mohrss.gov.cn/SYrlzyhshbzb/rdzt/zyjntsxd/zyjntsxd_xdzn/202011/t20201117_397433.html
#     联系人：商务部电子商务司  费云高
#     电  话：010-65197477
#     邮  箱：feiyungao@mofcom.gov.cn
#
#
# 商务部办公厅
# 2015年5月13日
# 附件：
# 1、“互联网+流通”行动计划
# ...

# %%
import pandas as pd
import re
import requests
import json
import os
from bs4 import BeautifulSoup

# %%
def get_html(u):
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36 FS"}
    r = requests.get(url=u, headers=headers)
    r.encoding = r.apparent_encoding
    return r.text

        
        
def save_file(url):
    text = get_html(url)
    soup = BeautifulSoup(text, 'lxml')
    txt = open('try.txt', 'w', encoding='utf-8')
    for each in soup.find_all('p'):
        if each.string:
            txt.writelines(each.string)
    txt.close()

# %%
def ff():
        import requests
        from bs4 import BeautifulSoup
        import jieba
        import requests
        df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
        web = df['网址']
        web_lst = []
        for w in web:
            web_lst.append(w)
        lst = []
        dics_counts={}
        for u in web_lst[119:276]:
            #print(web_lst.index(u)+2)
            save_file(u)
            txt = open('try.txt',encoding = 'utf-8').read()
            #加载停用词表
            stopwords = [line.strip() for line in open(r"D:\try\停用词.txt",encoding="utf-8").readlines()]
            words  = jieba.lcut(txt)
            if len(words) < 10:
                continue
            counts = {}
            lst_top3=[]
            for word in words:
            #不在停用词表中
                if word not in stopwords:
                #不统计字数为一的词
                    if len(word) == 1:
                        continue
                    else:
                        counts[word] = counts.get(word,0) + 1
            items = list(counts.items())
            items.sort(key=lambda x:x[1], reverse=True)
            for i in range(3):
                word, count = items[i]
                if word.isdigit():
                    continue
                else:
                    dics_counts[word]=dics_counts.get(word,0)+1
                    lst_top3.append(word)
            lst.append(lst_top3)
            dics_counts = dict(sorted(dics_counts.items(), key=lambda item:item[1], reverse=True))
        print(dics_counts)
        print(lst)
        '''print(lst_top3)
            print(counts)
            print(items)
            print()'''

# %%
ff()
# Out:
# {'青年': 36, '创业': 33, '企业': 28, '农村': 14, '创新': 11, '就业': 9, '科技': 8, '大学生': 7, '小微': 7, '全国': 7, '活动': 6, '小型': 6, '项目': 6, '基地': 6, '微利': 5, '高校': 5, '孵化': 5, '计划': 5, '贷款': 5, '毕业生': 4, '流通': 4, '志愿者': 4, '改革': 4, '留学人员': 4, '团委': 4, '培训': 4, '优惠政策': 3, '银行': 3, '大赛': 3, '公告': 3, '青少年': 3, '金融服务': 3, '候选人': 3, '中小企业': 2, '发行': 2, '融资': 2, '折旧': 2, '驱动': 2, '失业': 2, '资产': 2, '评价': 2, '奋斗': 2, '风险': 2, '提供': 2, '投资': 2, '国家税务总局': 2, '进一步': 2, '股份': 2, '精神': 2, '商贸': 2, '回国': 2, '农业': 2, '见习': 2, '竞赛': 2, '系统': 2, '资金': 2, '发行人': 1, '中国证监会': 1, '组委会': 1, '自贸': 1, '区内': 1, '跨境': 1, '返乡': 1, '意见': 1, '示范': 1, '城市': 1, '中国科协': 1, '加速': 1, '用地': 1, '产业': 1, '土地': 1, '国科': 1, '发火': 1, '月底': 1, '出台': 1, '具体措施': 1, '民营': 1, '银行业': 1, '财政部': 1, '人力资源': 1, '营业税': 1, '减免税': 1, '股权': 1, '划转': 1, '创业园': 1, '人才': 1, '互联网': 1, '行动计划': 1, '农场主': 1, '居民': 1, '三支': 1, '一扶': 1, '上市公司': 1, '证券': 1, '金融': 1, '典当行': 1, '个体': 1, '工商户': 1, '扣除': 1, '企业家': 1, '股东': 1, '资本': 1, '固定资产': 1, '补贴': 1, '向善': 1, '青
# ...

# %%
    import pandas as pd
    import re
    import requests
    from bs4 import BeautifulSoup
    import json
    import os
    def ff():
            import requests
            from bs4 import BeautifulSoup
            import jieba
            import requests
            headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36 FS"}
            df = pd.read_excel(r'C:\Users\HONEYMOON\Desktop\规划\中央创业政策2.xlsx')
            web = df['网址']
            web_lst = []
            for w in web:
                web_lst.append(w)
            lst = []
            dics_counts={}
            for u in web_lst[:118]:
                #print(web_lst.index(u)+2)
                r = requests.get(url=u, headers=headers)
                r.encoding = r.apparent_encoding
                text1 = r.text
                soup = BeautifulSoup(text1, 'lxml')
            txt = open('fff.txt', 'w', encoding='utf-8')
            for each in soup.find_all('p'):
                if each.string:
                    txt.writelines(each.string)
            txt.close()
            txt = open('fff.txt',encoding = 'utf-8').read()
            #加载停用词表
            stopwords = [line.strip() for line in open(r"D:\try\停用词.txt",encoding="utf-8").readlines()]
            words  = jieba.lcut(txt)
            counts = {}
            lst_top3=[]
            for word in words:
            #不在停用词表中
                if word not in stopwords:
                #不统计字数为一的词
                    if len(word) == 1:
                        continue
                    else:
                        counts[word] = counts.get(word,0) + 1
            items = list(counts.items())
            items.sort(key=lambda x:x[1], reverse=True)
            for i in range(3):
                word, count = items[i]
                if word.isdigit():
                    continue
                else:
                    dics_counts[word]=dics_counts.get(word,0)+1
                    lst_top3.append(word)
            lst.append(lst_top3)
            dics_counts = dict(sorted(dics_counts.items(), key=lambda item:item[1], reverse=True))
            print(dics_counts)
            print(lst)
            '''print(lst_top3)
            print(counts)
            print(items)
            print()'''

# %%
ff()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\HONEYM~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.447 seconds.
# Prefix dict has been built successfully.
# {'社部': 1, '主办单位': 1, '中华人民共和国': 1}
# [['社部', '主办单位', '中华人民共和国']]

# %%
import requests
import json
from bs4 import BeautifulSoup
import re
import os
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36 FS"}

def get_html(url):
    r = requests.get(url=url, headers=headers)
    r.encoding = r.apparent_encoding
    print("状态：", r.raise_for_status)
    return r.text

def get_json(url):
    r = requests.get(url=url, headers=headers)
    r.encoding = r.apparent_encoding
    print("状态：", r.raise_for_status)
    return r.json()

def get_url_list(json_text):
    url_dict = dict()
    for each in json_text['searchVO']['catMap']['gongwen']['listVO']:
        url_dict[each['url']] = each['title'].replace('<em>','').replace('</em>','')
    for each in json_text['searchVO']['catMap']['otherfile']['listVO']:
        url_dict[each['url']] = each['title'].replace('<em>','').replace('</em>','')
    return url_dict

def get_all_link():
    url_dict = dict()
    for i in range(3):
        url=f'http://sousuo.gov.cn/data?t=zhengce&q=%E6%88%BF%E5%9C%B0%E4%BA%A7&timetype=timeqb&mintime=&maxtime=&sort=&sortType=1&searchfield=title&pcodeJiguan=&childtype=&subchildtype=&tsbq=&pubtimeyear=&puborg=&pcodeYear=&pcodeNum=&filetype=&p={i}&n=5&inpro='
        json_text = get_json(url)
        dic = get_url_list(json_text)
        if not dic:
            break
        url_dict.update(dic)
    return url_dict

def save_file(url, title):
    text = get_html(url)
    soup = BeautifulSoup(text, 'lxml')
    fp = open(f'../file/{title}.txt', 'w', encoding='utf-8')
    for each in soup.find_all('p'):
        if each.string:
            fp.writelines(each.string)
    fp.close()
    print("写入成功")

def main():
    if not os.path.exists('../file/'):
        os.makedirs('../file/')
    url_dict = get_all_link()
    for url in url_dict:
        save_file(url, url_dict[url])

main()
